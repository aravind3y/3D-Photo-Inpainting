# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind3y/3D-Photo-Inpainting/blob/master/3D_Photo_Inpainting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **[CVPR 2020] 3D Photography using Context-aware Layered Depth Inpainting**
#
# [project website](https://shihmengli.github.io/3D-Photo-Inpainting/)

# %% [markdown]
# - **Prepare environment**

# %%
# !pip3 install torch==1.4.0+cu100 torchvision==0.5.0+cu100 -f https://download.pytorch.org/whl/torch_stable.html
# !pip3 install opencv-python==4.2.0.32
# !pip3 install vispy==0.6.4
# !pip3 install moviepy==1.0.2
# !pip3 install transforms3d==0.3.1
# !pip3 install networkx==2.3
# !sudo apt install sed
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.4.0+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torch-1.4.0%2Bcu100-cp36-cp36m-linux_x86_64.whl (723.9MB)
#      |████████████████████████████████| 723.9MB 24kB/s
# Collecting torchvision==0.5.0+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torchvision-0.5.0%2Bcu100-cp36-cp36m-linux_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.1MB 44.6MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu100) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu100) (7.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu100) (1.18.5)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.5.1+cu101
#     Uninstalling torch-1.5.1+cu101:
#       Successfully uninstalled torch-1.5.1+cu101
#   Found existing installation: torchvision 0.6.1+cu101
#     Uninstalling torchvision-0.6.1+cu101:
#       Successfully uninstalled torchvision-0.6.1+cu101
# Successfully installed torch-1.4.0+cu100 torchvision-0.5.0+cu100
# Collecting opencv-python==4.2.0.32
#   Downloading https://files.pythonhosted.org/packages/68/c5/09a1b82f940805c2cee30c3c42786651edcfd0710a0283eb09c6bc959340/opencv_python-4.2.0.32-cp36-cp36m-manylinux1_x86_64.whl (28.2MB)
#      |████████████████████████████████| 28.2MB 110kB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==4.2.0.32) (1.18.5)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-4.2.0.32
# Collecting vispy==0.6.4
#   Downloading https://files.pythonhosted.org/packages/cf/29/899797a9af4446d3ddf594f49b0fbd43076eafa1552e24690cfd99b0e2ff/vispy-0.6.4-cp36-cp36m-manylinux2010_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 8.1MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from vispy==0.6.4) (1.18.5)
# Collecting freetype-py
#   Downloading https://files.pythonhosted.org/packages/40/b5/56751e13f8b4a42f52c1b85ecce1446f83245190d820b42748eb8574ae43/freetype_py-2.2.0-py3-none-manylinux1_x86_64.whl (890kB)
#      |████████████████████████████████| 890kB 53.0MB/s
# Installing collected packages: freetype-py, vispy
# Successfully installed freetype-py-2.2.0 vispy-0.6.4
# Collecting moviepy==1.0.2
#   Downloading https://files.pythonhosted.org/packages/71/64/e7f0876716d5c35612bf8e9e49299d0f491285f10f36cbb481556ab0062b/moviepy-1.0.2.tar.gz (7.8MB)
#      |████████████████████████████████| 7.9MB 8.1MB/s
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.6/dist-packages (from moviepy==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.6/dist-packages (from moviepy==1.0.2) (4.41.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.6/dist-packages (from moviepy==1.0.2) (2.23.0)
# Collecting proglog<=1.0.0
#   Downloading https://files.pythonhosted.org/packages/fe/ab/4cb19b578e1364c0b2d6efd6521a8b4b4e5c4ae6528041d31a2a951dd991/proglog-0.1.9.tar.gz
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.6/dist-packages (from moviepy==1.0.2) (1.18.5)
# Collecting imageio<3.0,>=2.5
#   Downloading https://files.pythonhosted.org/packages/6e/57/5d899fae74c1752f52869b613a8210a2480e1a69688e65df6cb26117d45d/imageio-2.9.0-py3-none-any.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 50.4MB/s
# Collecting imageio_ffmpeg>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/df/c8/04c6b4a001b8ae7326fb83d6665af1ee58d6cc1acb421f8ea40d2678fe3c/imageio_ffmpeg-0.4.2-py3-none-manylinux2010_x86_64.whl (26.9MB)
#      |████████████████████████████████| 26.9MB 94kB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (3.0.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from imageio<3.0,>=2.5->moviepy==1.0.2) (7.0.0)
# Building wheels for collected packages: moviepy, proglog
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.2-cp36-none-any.whl size=110730 sha256=2d09038af603945897dbdd519693366248e99890bb942f6426ea751ea9b6d233
#   Stored in directory: /root/.cache/pip/wheels/20/49/a9/770a9a22e7a020d796ab3784d2dc4839e38450a1ac87e6106f
#   Building wheel for proglog (setup.py) ... done
#   Created wheel for proglog: filename=proglog-0.1.9-cp36-none-any.whl size=6149 sha256=dedbd48b1f1a4c7c0903030b2f672b630d1c0d7bd55bf6ee306da256dedf627f
#   Stored in directory: /root/.cache/pip/wheels/65/56/60/1d0306a8d90b188af393c1812ddb502a8821b70917f82dcc00
# Successfully built moviepy proglog
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: proglog, imageio, imageio-ffmpeg, moviepy
#   Found existing installation: imageio 2.4.1
#     Uninstalling imageio-2.4.1:
#       Successfully uninstalled imageio-2.4.1
#   Found existing installation: moviepy 0.2.3.5
#     Uninstalling moviepy-0.2.3.5:
#       Successfully uninstalled moviepy-0.2.3.5
# Successfully installed imageio-2.9.0 imageio-ffmpeg-0.4.2 moviepy-1.0.2 proglog-0.1.9
# Collecting transforms3d==0.3.1
#   Downloading https://files.pythonhosted.org/packages/b5/f7/e85809168a548a854d7c1331560c27b4f5381698d29c12e57759192b2bc1/transforms3d-0.3.1.tar.gz (62kB)
#      |████████████████████████████████| 71kB 5.1MB/s
# Building wheels for collected packages: transforms3d
#   Building wheel for transforms3d (setup.py) ... done
#   Created wheel for transforms3d: filename=transforms3d-0.3.1-cp36-none-any.whl size=59375 sha256=e4c7f100dd431bdfed4da365ad83f67ffa8a4a43960ebf60e254412d19ff189d
#   Stored in directory: /root/.cache/pip/wheels/3d/3c/84/28d36677f3c760c048bd02b5a547ea0c4027770cc9cdb9af1e
# Successfully built transforms3d
# Installing collected packages: transforms3d
# Successfully installed transforms3d-0.3.1
# Collecting networkx==2.3
#   Downloading https://files.pythonhosted.org/packages/85/08/f20aef11d4c343b557e5de6b9548761811eb16e438cee3d32b1c66c8566b/networkx-2.3.zip (1.7MB)
#      |████████████████████████████████| 1.8MB 9.4MB/s
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx==2.3) (4.4.2)
# Building wheels for collected packages: networkx
#   Building wheel for networkx (setup.py) ... done
#   Created wheel for networkx: filename=networkx-2.3-py2.py3-none-any.whl size=1556408 sha256=619a0e157a512274cfb6ff294d2394770e099a7bf03bc2f821131541fa5e1b01
#   Stored in directory: /root/.cache/pip/wheels/de/63/64/3699be2a9d0ccdb37c7f16329acf3863fd76eda58c39c737af
# Successfully built networkx
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: networkx
#   Found existing installation: networkx 2.4
#     Uninstalling networkx-2.4:
#       Successfully uninstalled networkx-2.4
# Successfully installed networkx-2.3
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# sed is already the newest version (4.4-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %% [markdown]
# - **Download script and pretrained model**

# %%
# %cd /content/
# !git clone https://github.com/vt-vl-lab/3d-photo-inpainting.git
# %cd 3d-photo-inpainting
# !sh download.sh
# Out:
# /content
# Cloning into '3d-photo-inpainting'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 350 (delta 2), reused 3 (delta 0), pack-reused 344
# Receiving objects: 100% (350/350), 130.13 MiB | 22.02 MiB/s, done.
# Resolving deltas: 100% (191/191), done.
# /content/3d-photo-inpainting
# downloading from filebox ...
# --2020-07-24 13:15:33--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/color-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 206331633 (197M)
# Saving to: ‘color-model.pth’
#
# color-model.pth     100%[===================>] 196.77M  7.97MB/s    in 18s
#
# 2020-07-24 13:15:51 (11.0 MB/s) - ‘color-model.pth’ saved [206331633/206331633]
#
# --2020-07-24 13:15:51--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/depth-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 206272258 (197M)
# Saving to: ‘depth-model.pth’
#
# depth-model.pth     100%[===================>] 196.72M  14.8MB/s    in 13s
#
# 2020-07-24 13:16:04 (15.4 MB/s) - ‘depth-model.pth’ saved [206272258/206272258]
#
# --2020-07-24 13:16:04--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/edge-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45974122 (44M)
# Saving to: ‘edge-model.pth’
#
# edge-model.pth      100%[===================>]  43.84M  12.1MB/s    in 3.8s
#
# 2020-07-24 13:16:09 (11.6 MB/s) - ‘edge-model.pth’ saved [45974122/45974122]
#
# --2020-07-24 13:16:09--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/model.pt
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149751722 (143M)
# Saving to: ‘model.pt’
#
# model.pt            100%[===================>] 142.81M  18.6MB/s    in 23s
#
# 2020-07-24 13:16:32 (6.22 MB/s) - ‘model.pt’ saved [149751722/149751722]

# %% [markdown]
# - **Switch off off-screen rendering**

# %%
# !sed -i 's/offscreen_rendering: True/offscreen_rendering: False/g' argument.yml

# %% [markdown]
# - **Please upload `.jpg` files to `/content/3d-photo-inpainting-master/image/`**
#   - You can run this step multiple times to upload multiple `.jpg` files.

# %%
# %cd image
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# %cd ..
# Out:
# /content/3d-photo-inpainting/image
#      <input type="file" id="files-886176db-f2c1-42c0-bed8-aa83314bea73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-886176db-f2c1-42c0-bed8-aa83314bea73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving profile.jpg to profile.jpg
# User uploaded file "profile.jpg" with length 798689 bytes
# /content/3d-photo-inpainting

# %% [markdown]
# - **Execute the 3D Photo Inpainting**
#   - Note: The 3D photo generation process usually takes about 2-3 minutes or more depending on the available computing resources.

# %%
# !python main.py --config argument.yml
# Out:
# running on device 0
#   0% 0/2 [00:00<?, ?it/s]Current Source ==>  profile
# Running depth extraction at 1595596722.273057
# initialize
# device: cpu
# start processing
#   processing image/profile.jpg (1/1)
# torch.Size([1, 3, 384, 384])
# finished
# Start Running 3D_Photo ...
# Loading edge model at 1595596738.995747
# Loading depth model at 1595596742.5429616
# Loading rgb model at 1595596743.3253517
# Writing depth ply (and basically doing everything) at 1595596744.024362
# Writing mesh file mesh/profile.ply ...
# Making video at 1595596907.952377
# fov: 53.13010235415598
# Moviepy - Building video video/profile_dolly-zoom-in.mp4.
# Moviepy - Writing video video/profile_dolly-zoom-in.mp4
#
#   0% 0/2 [03:44<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   1% 2/241 [00:00<00:37,  6.38it/s, now=None]
# t:   1% 3/241 [00:00<00:34,  6.95it/s, now=None]
# t:   6% 14/241 [00:00<00:23,  9.64it/s, now=None]
# t:  10% 25/241 [00:00<00:16, 13.27it/s, now=None]
# t:  16% 38/241 [00:00<00:11, 18.16it/s, now=None]
# t:  20% 47/241 [00:00<00:08, 23.84it/s, now=None]
# t:  23% 56/241 [00:01<00:07, 24.31it/s, now=None]
# t:  26% 63/241 [00:01<00:06, 26.65it/s, now=None]
# t:  29% 69/241 [00:01<00:05, 29.64it/s, now=None]
# t:  31% 75/241 [00:01<00:05, 29.92it/s, now=None]
# t:  33% 80/241 [00:01<00:05, 31.70it/s, now=None]
# t:  35% 85/241 [00:01<00:04, 34.35it/s, now=None]
# t:  37% 90/241 [00:02<00:04, 34.19it/s, now=None]
# t:  39% 95/241 [00:02<00:04, 33.15it/s, now=None]
# t:  41% 99/241 [00:02<00:04, 33.30it/s, now=None]
# t:  43% 103/241 [00:02<00:03, 34.53it/s, now=None]
# t:  44% 107/241 [00:02<00:03, 33.96it/s, now=None]
# t:  46% 111/241 [00:02<00:03, 33.64it/s, now=None]
# t:  48% 115/241 [00:02<00:03, 34.84it/s, now=None]
# t:  49% 119/241 [00:02<00:03, 34.51it/s, now=None]
# t:  51% 123/241 [00:03<00:03, 35.12it/s, now=None]
# t:  53% 127/241 [00:03<00:03, 34.99it/s, now=None]
# t:  54% 131/241 [00:03<00:03, 35.35it/s, now=None]
# t:  56% 135/241 [00:03<00:03, 35.29it/s, now=None]
# t:  58% 139/241 [00:03<00:02, 35.50it/s, now=None]
# t:  59% 143/241 [00:03<00:02, 35.44it/s, now=None]
# t:  61% 147/241 [00:03<00:02, 34.77it/s, now=None]
# t:  63% 151/241 [00:03<00:02, 34.76it/s, now=None]
# t:  64% 155/241 [00:04<00:02, 35.37it/s, now=None]
# t:  66% 159/241 [00:04<00:02, 35.89it/s, now=None]
# t:  68% 163/241 [00:04<00:02, 35.74it/s, now=None]
# t:  69% 167/241 [00:04<00:02, 35.49it/s, now=None]
# t:  71% 171/241 [00:04<00:01, 36.15it/s, now=None]
# t:  73% 175/241 [00:04<00:01, 35.70it/s, now=None]
# t:  74% 179/241 [00:04<00:01, 34.16it/s, now=None]
# t:  76% 183/241 [00:04<00:01, 34.77it/s, now=None]
# t:  78% 187/241 [00:04<00:01, 35.19it/s, now=None]
# t:  79% 191/241 [00:05<00:01, 35.45it/s, now=None]
# t:  81% 195/241 [00:05<00:01, 36.53it/s, now=None]
# t:  83% 199/241 [00:05<00:01, 35.85it/s, now=None]
# t:  84% 203/241 [00:05<00:01, 35.09it/s, now=None]
# t:  86% 207/241 [00:05<00:00, 35.04it/s, now=None]
# t:  88% 211/241 [00:05<00:00, 34.74it/s, now=None]
# t:  89% 215/241 [00:05<00:00, 34.76it/s, now=None]
# t:  91% 219/241 [00:05<00:00, 34.79it/s, now=None]
# t:  93% 223/241 [00:05<00:00, 35.16it/s, now=None]
# t:  94% 227/241 [00:06<00:00, 35.82it/s, now=None]
# t:  96% 231/241 [00:06<00:00, 34.11it/s, now=None]
# t:  98% 235/241 [00:06<00:00, 34.10it/s, now=None]
# t:  99% 239/241 [00:06<00:00, 33.78it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/profile_dolly-zoom-in.mp4
# Moviepy - Building video video/profile_zoom-in.mp4.
# Moviepy - Writing video video/profile_zoom-in.mp4
#
#   0% 0/2 [04:26<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   5% 12/241 [00:00<00:02, 112.57it/s, now=None]
# t:  10% 23/241 [00:00<00:01, 111.57it/s, now=None]
# t:  15% 35/241 [00:00<00:01, 108.83it/s, now=None]
# t:  19% 46/241 [00:00<00:01, 106.18it/s, now=None]
# t:  22% 54/241 [00:00<00:03, 53.01it/s, now=None]
# t:  25% 61/241 [00:01<00:04, 41.06it/s, now=None]
# t:  28% 67/241 [00:01<00:04, 35.56it/s, now=None]
# t:  30% 72/241 [00:01<00:04, 35.05it/s, now=None]
# t:  32% 77/241 [00:01<00:04, 34.03it/s, now=None]
# t:  34% 81/241 [00:01<00:04, 35.03it/s, now=None]
# t:  35% 85/241 [00:01<00:04, 34.40it/s, now=None]
# t:  37% 89/241 [00:01<00:05, 29.93it/s, now=None]
# t:  39% 93/241 [00:02<00:04, 31.48it/s, now=None]
# t:  40% 97/241 [00:02<00:04, 32.45it/s, now=None]
# t:  42% 101/241 [00:02<00:04, 31.32it/s, now=None]
# t:  44% 105/241 [00:02<00:04, 30.76it/s, now=None]
# t:  45% 109/241 [00:02<00:04, 28.81it/s, now=None]
# t:  47% 113/241 [00:02<00:04, 29.55it/s, now=None]
# t:  49% 117/241 [00:02<00:04, 30.95it/s, now=None]
# t:  50% 121/241 [00:02<00:03, 31.94it/s, now=None]
# t:  52% 125/241 [00:03<00:03, 31.62it/s, now=None]
# t:  54% 129/241 [00:03<00:03, 29.90it/s, now=None]
# t:  55% 133/241 [00:03<00:03, 30.10it/s, now=None]
# t:  57% 137/241 [00:03<00:03, 30.66it/s, now=None]
# t:  59% 141/241 [00:03<00:03, 30.73it/s, now=None]
# t:  60% 145/241 [00:03<00:03, 30.56it/s, now=None]
# t:  62% 149/241 [00:03<00:02, 30.72it/s, now=None]
# t:  63% 153/241 [00:04<00:02, 29.49it/s, now=None]
# t:  65% 157/241 [00:04<00:02, 29.84it/s, now=None]
# t:  66% 160/241 [00:04<00:02, 29.80it/s, now=None]
# t:  68% 163/241 [00:04<00:02, 27.31it/s, now=None]
# t:  69% 167/241 [00:04<00:02, 28.57it/s, now=None]
# t:  71% 171/241 [00:04<00:02, 29.18it/s, now=None]
# t:  73% 175/241 [00:04<00:02, 29.73it/s, now=None]
# t:  74% 179/241 [00:04<00:02, 29.96it/s, now=None]
# t:  76% 183/241 [00:05<00:01, 31.11it/s, now=None]
# t:  78% 187/241 [00:05<00:01, 29.85it/s, now=None]
# t:  79% 191/241 [00:05<00:01, 28.10it/s, now=None]
# t:  81% 195/241 [00:05<00:01, 28.09it/s, now=None]
# t:  83% 199/241 [00:05<00:01, 28.33it/s, now=None]
# t:  84% 203/241 [00:05<00:01, 28.81it/s, now=None]
# t:  86% 207/241 [00:05<00:01, 29.94it/s, now=None]
# t:  88% 211/241 [00:06<00:01, 29.53it/s, now=None]
# t:  89% 215/241 [00:06<00:00, 29.01it/s, now=None]
# t:  91% 219/241 [00:06<00:00, 29.21it/s, now=None]
# t:  93% 223/241 [00:06<00:00, 29.55it/s, now=None]
# t:  94% 227/241 [00:06<00:00, 29.83it/s, now=None]
# t:  96% 231/241 [00:06<00:00, 30.28it/s, now=None]
# t:  98% 235/241 [00:06<00:00, 30.90it/s, now=None]
# t:  99% 239/241 [00:06<00:00, 30.44it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/profile_zoom-in.mp4
# Moviepy - Building video video/profile_circle.mp4.
# Moviepy - Writing video video/profile_circle.mp4
#
#   0% 0/2 [05:08<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   4% 10/241 [00:00<00:02, 94.15it/s, now=None]
# t:   9% 22/241 [00:00<00:02, 99.02it/s, now=None]
# t:  14% 33/241 [00:00<00:02, 101.18it/s, now=None]
# t:  17% 42/241 [00:00<00:02, 96.92it/s, now=None]
# t:  21% 50/241 [00:00<00:04, 46.28it/s, now=None]
# t:  23% 56/241 [00:00<00:04, 41.06it/s, now=None]
# t:  26% 62/241 [00:01<00:04, 37.26it/s, now=None]
# t:  28% 67/241 [00:01<00:05, 32.37it/s, now=None]
# t:  29% 71/241 [00:01<00:05, 31.45it/s, now=None]
# t:  31% 75/241 [00:01<00:05, 29.64it/s, now=None]
# t:  33% 79/241 [00:01<00:05, 28.97it/s, now=None]
# t:  34% 83/241 [00:01<00:05, 27.77it/s, now=None]
# t:  36% 87/241 [00:02<00:05, 27.65it/s, now=None]
# t:  37% 90/241 [00:02<00:05, 27.86it/s, now=None]
# t:  39% 93/241 [00:02<00:05, 26.49it/s, now=None]
# t:  40% 97/241 [00:02<00:04, 28.95it/s, now=None]
# t:  42% 101/241 [00:02<00:05, 25.87it/s, now=None]
# t:  44% 105/241 [00:02<00:04, 28.03it/s, now=None]
# t:  45% 108/241 [00:02<00:05, 25.36it/s, now=None]
# t:  46% 111/241 [00:03<00:04, 26.11it/s, now=None]
# t:  47% 114/241 [00:03<00:04, 27.16it/s, now=None]
# t:  49% 117/241 [00:03<00:04, 26.51it/s, now=None]
# t:  50% 121/241 [00:03<00:04, 26.27it/s, now=None]
# t:  51% 124/241 [00:03<00:04, 26.64it/s, now=None]
# t:  53% 127/241 [00:03<00:04, 26.65it/s, now=None]
# t:  54% 130/241 [00:03<00:04, 26.85it/s, now=None]
# t:  55% 133/241 [00:03<00:04, 25.69it/s, now=None]
# t:  57% 137/241 [00:03<00:03, 27.76it/s, now=None]
# t:  58% 140/241 [00:04<00:03, 25.96it/s, now=None]
# t:  59% 143/241 [00:04<00:03, 26.90it/s, now=None]
# t:  61% 147/241 [00:04<00:03, 28.49it/s, now=None]
# t:  62% 150/241 [00:04<00:03, 27.76it/s, now=None]
# t:  63% 153/241 [00:04<00:03, 27.67it/s, now=None]
# t:  65% 156/241 [00:04<00:03, 27.40it/s, now=None]
# t:  66% 160/241 [00:04<00:02, 29.08it/s, now=None]
# t:  68% 163/241 [00:04<00:02, 27.98it/s, now=None]
# t:  69% 166/241 [00:05<00:02, 26.80it/s, now=None]
# t:  70% 169/241 [00:05<00:02, 27.07it/s, now=None]
# t:  72% 173/241 [00:05<00:02, 27.39it/s, now=None]
# t:  73% 177/241 [00:05<00:02, 27.51it/s, now=None]
# t:  75% 181/241 [00:05<00:02, 27.87it/s, now=None]
# t:  77% 185/241 [00:05<00:02, 27.09it/s, now=None]
# t:  78% 189/241 [00:05<00:01, 26.69it/s, now=None]
# t:  80% 192/241 [00:05<00:01, 26.43it/s, now=None]
# t:  81% 196/241 [00:06<00:01, 28.91it/s, now=None]
# t:  83% 199/241 [00:06<00:01, 27.94it/s, now=None]
# t:  84% 202/241 [00:06<00:01, 26.12it/s, now=None]
# t:  85% 205/241 [00:06<00:01, 25.65it/s, now=None]
# t:  87% 209/241 [00:06<00:01, 25.52it/s, now=None]
# t:  88% 212/241 [00:06<00:01, 26.48it/s, now=None]
# t:  89% 215/241 [00:06<00:01, 25.16it/s, now=None]
# t:  90% 218/241 [00:06<00:00, 24.95it/s, now=None]
# t:  92% 221/241 [00:07<00:00, 24.45it/s, now=None]
# t:  93% 225/241 [00:07<00:00, 25.43it/s, now=None]
# t:  95% 229/241 [00:07<00:00, 25.61it/s, now=None]
# t:  97% 233/241 [00:07<00:00, 25.90it/s, now=None]
# t:  98% 237/241 [00:07<00:00, 26.03it/s, now=None]
# t: 100% 241/241 [00:07<00:00, 27.23it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/profile_circle.mp4
# Moviepy - Building video video/profile_swing.mp4.
# Moviepy - Writing video video/profile_swing.mp4
#
#   0% 0/2 [05:52<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   4% 10/241 [00:00<00:02, 93.70it/s, now=None]
# t:   9% 21/241 [00:00<00:02, 97.31it/s, now=None]
# t:  14% 34/241 [00:00<00:01, 104.23it/s, now=None]
# t:  19% 46/241 [00:00<00:01, 105.73it/s, now=None]
# t:  23% 55/241 [00:00<00:03, 50.11it/s, now=None]
# t:  26% 62/241 [00:01<00:04, 40.47it/s, now=None]
# t:  28% 68/241 [00:01<00:04, 35.08it/s, now=None]
# t:  30% 73/241 [00:01<00:04, 34.39it/s, now=None]
# t:  32% 78/241 [00:01<00:04, 33.78it/s, now=None]
# t:  34% 82/241 [00:01<00:04, 31.98it/s, now=None]
# t:  36% 86/241 [00:01<00:05, 30.27it/s, now=None]
# t:  37% 90/241 [00:02<00:04, 30.51it/s, now=None]
# t:  39% 94/241 [00:02<00:04, 29.65it/s, now=None]
# t:  41% 98/241 [00:02<00:05, 28.35it/s, now=None]
# t:  42% 101/241 [00:02<00:04, 28.28it/s, now=None]
# t:  43% 104/241 [00:02<00:05, 27.38it/s, now=None]
# t:  45% 108/241 [00:02<00:04, 27.13it/s, now=None]
# t:  46% 112/241 [00:02<00:04, 27.26it/s, now=None]
# t:  48% 116/241 [00:02<00:04, 27.45it/s, now=None]
# t:  50% 120/241 [00:03<00:04, 26.79it/s, now=None]
# t:  51% 124/241 [00:03<00:04, 26.63it/s, now=None]
# t:  53% 128/241 [00:03<00:04, 27.40it/s, now=None]
# t:  55% 132/241 [00:03<00:04, 27.21it/s, now=None]
# t:  56% 136/241 [00:03<00:03, 26.68it/s, now=None]
# t:  58% 139/241 [00:03<00:03, 27.34it/s, now=None]
# t:  59% 142/241 [00:03<00:03, 26.84it/s, now=None]
# t:  60% 145/241 [00:04<00:03, 27.19it/s, now=None]
# t:  61% 148/241 [00:04<00:03, 25.89it/s, now=None]
# t:  63% 152/241 [00:04<00:03, 26.32it/s, now=None]
# t:  65% 156/241 [00:04<00:03, 26.98it/s, now=None]
# t:  66% 160/241 [00:04<00:02, 27.86it/s, now=None]
# t:  68% 164/241 [00:04<00:02, 28.39it/s, now=None]
# t:  70% 168/241 [00:04<00:02, 29.42it/s, now=None]
# t:  72% 173/241 [00:05<00:02, 30.90it/s, now=None]
# t:  73% 177/241 [00:05<00:02, 30.96it/s, now=None]
# t:  75% 181/241 [00:05<00:02, 28.68it/s, now=None]
# t:  76% 184/241 [00:05<00:01, 28.55it/s, now=None]
# t:  78% 188/241 [00:05<00:01, 28.61it/s, now=None]
# t:  79% 191/241 [00:05<00:01, 28.72it/s, now=None]
# t:  80% 194/241 [00:05<00:01, 28.62it/s, now=None]
# t:  82% 197/241 [00:05<00:01, 27.99it/s, now=None]
# t:  83% 200/241 [00:05<00:01, 28.16it/s, now=None]
# t:  85% 204/241 [00:06<00:01, 28.05it/s, now=None]
# t:  86% 208/241 [00:06<00:01, 27.75it/s, now=None]
# t:  88% 212/241 [00:06<00:01, 27.83it/s, now=None]
# t:  90% 216/241 [00:06<00:00, 27.98it/s, now=None]
# t:  91% 220/241 [00:06<00:00, 27.77it/s, now=None]
# t:  93% 224/241 [00:06<00:00, 27.54it/s, now=None]
# t:  95% 228/241 [00:06<00:00, 27.55it/s, now=None]
# t:  96% 232/241 [00:07<00:00, 27.49it/s, now=None]
# t:  98% 236/241 [00:07<00:00, 26.98it/s, now=None]
# t: 100% 240/241 [00:07<00:00, 27.92it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/profile_swing.mp4
#  50% 1/2 [06:01<06:01, 361.34s/it]Current Source ==>  moon
# Running depth extraction at 1595597083.6457222
# initialize
# device: cpu
# start processing
#   processing image/moon.jpg (1/1)
# torch.Size([1, 3, 384, 384])
# finished
# Start Running 3D_Photo ...
# Loading edge model at 1595597102.9198093
# Loading depth model at 1595597104.3154318
# Loading rgb model at 1595597110.5163364
# Writing depth ply (and basically doing everything) at 1595597116.7211952
# Writing mesh file mesh/moon.ply ...
# Making video at 1595597287.212542
# fov: 53.13010235415598
# Moviepy - Building video video/moon_dolly-zoom-in.mp4.
# Moviepy - Writing video video/moon_dolly-zoom-in.mp4
#
#  50% 1/2 [10:00<06:01, 361.34s/it]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   1% 2/241 [00:00<00:37,  6.34it/s, now=None]
# t:   1% 3/241 [00:00<00:34,  6.85it/s, now=None]
# t:   6% 14/241 [00:00<00:23,  9.53it/s, now=None]
# t:  11% 27/241 [00:00<00:16, 13.19it/s, now=None]
# t:  16% 39/241 [00:00<00:11, 17.98it/s, now=None]
# t:  20% 48/241 [00:00<00:08, 21.66it/s, now=None]
# t:  23% 55/241 [00:01<00:08, 22.20it/s, now=None]
# t:  25% 61/241 [00:01<00:07, 24.32it/s, now=None]
# t:  27% 66/241 [00:01<00:07, 23.98it/s, now=None]
# t:  29% 71/241 [00:01<00:06, 24.30it/s, now=None]
# t:  31% 75/241 [00:02<00:06, 24.63it/s, now=None]
# t:  33% 79/241 [00:02<00:06, 25.16it/s, now=None]
# t:  34% 83/241 [00:02<00:06, 25.13it/s, now=None]
# t:  36% 87/241 [00:02<00:06, 25.57it/s, now=None]
# t:  38% 91/241 [00:02<00:05, 25.59it/s, now=None]
# t:  39% 95/241 [00:02<00:05, 25.89it/s, now=None]
# t:  41% 99/241 [00:02<00:05, 25.17it/s, now=None]
# t:  43% 103/241 [00:03<00:05, 25.43it/s, now=None]
# t:  44% 107/241 [00:03<00:05, 26.17it/s, now=None]
# t:  46% 111/241 [00:03<00:04, 26.02it/s, now=None]
# t:  47% 114/241 [00:03<00:04, 25.88it/s, now=None]
# t:  49% 118/241 [00:03<00:04, 27.65it/s, now=None]
# t:  50% 121/241 [00:03<00:04, 27.47it/s, now=None]
# t:  51% 124/241 [00:03<00:04, 25.64it/s, now=None]
# t:  53% 127/241 [00:04<00:04, 24.10it/s, now=None]
# t:  54% 131/241 [00:04<00:04, 24.44it/s, now=None]
# t:  56% 135/241 [00:04<00:04, 24.60it/s, now=None]
# t:  58% 139/241 [00:04<00:04, 24.75it/s, now=None]
# t:  59% 142/241 [00:04<00:03, 25.83it/s, now=None]
# t:  61% 146/241 [00:04<00:03, 26.67it/s, now=None]
# t:  62% 149/241 [00:04<00:03, 27.53it/s, now=None]
# t:  63% 152/241 [00:05<00:03, 25.17it/s, now=None]
# t:  64% 155/241 [00:05<00:03, 24.09it/s, now=None]
# t:  66% 159/241 [00:05<00:03, 24.42it/s, now=None]
# t:  67% 162/241 [00:05<00:03, 25.46it/s, now=None]
# t:  68% 165/241 [00:05<00:02, 25.98it/s, now=None]
# t:  70% 168/241 [00:05<00:02, 24.60it/s, now=None]
# t:  71% 171/241 [00:05<00:02, 23.42it/s, now=None]
# t:  73% 175/241 [00:05<00:02, 24.28it/s, now=None]
# t:  74% 179/241 [00:06<00:02, 24.47it/s, now=None]
# t:  76% 183/241 [00:06<00:02, 25.03it/s, now=None]
# t:  77% 186/241 [00:06<00:02, 25.79it/s, now=None]
# t:  79% 190/241 [00:06<00:01, 27.46it/s, now=None]
# t:  80% 193/241 [00:06<00:01, 24.83it/s, now=None]
# t:  81% 196/241 [00:06<00:01, 25.66it/s, now=None]
# t:  83% 199/241 [00:06<00:01, 24.70it/s, now=None]
# t:  84% 203/241 [00:07<00:01, 25.05it/s, now=None]
# t:  86% 207/241 [00:07<00:01, 25.34it/s, now=None]
# t:  88% 211/241 [00:07<00:01, 25.48it/s, now=None]
# t:  89% 215/241 [00:07<00:01, 25.29it/s, now=None]
# t:  91% 219/241 [00:07<00:00, 25.15it/s, now=None]
# t:  93% 223/241 [00:07<00:00, 25.64it/s, now=None]
# t:  94% 227/241 [00:07<00:00, 25.90it/s, now=None]
# t:  96% 231/241 [00:08<00:00, 25.29it/s, now=None]
# t:  98% 235/241 [00:08<00:00, 25.63it/s, now=None]
# t:  99% 239/241 [00:08<00:00, 25.39it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_dolly-zoom-in.mp4
#  50% 1/2 [10:10<06:01, 361.34s/it]^C

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# - **The results are stored in the following directories**
#   - Corresponding depth map estimated by [MiDaS](https://github.com/intel-isl/MiDaS.git)
#       - E.g. ```/content/3d-photo-inpainting/depth/moon.npy```
#   - Inpainted 3D mesh
#       - E.g. ```/content/3d-photo-inpainting/mesh/moon.ply```
#   - Rendered videos with zoom-in motion
#       - E.g. ```/content/3d-photo-inpainting/video/moon_zoom-in.mp4```
#   - Rendered videos with swing motion
#       - E.g. ```/content/3d-photo-inpainting/video/moon_swing.mp4```
#   - Rendered videos with circle motion
#       - E.g. ```/content/3d-photo-inpainting/video/moon_circle.mp4```
#
#     ![](https://drive.google.com/uc?id=1xBiZAeGfhsoAsG08N5UM8-f993p0G5HF)
